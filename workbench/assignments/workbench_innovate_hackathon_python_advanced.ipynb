# %% [markdown]
# ### Example 3.6 Community Detection on Zachary’s Karate Club Data
#
# This example uses Zachary’s Karate Club data (Zachary 1977), which describes social network friendships between 34 members of a karate club at a US university in the 1970s. This is one of the standard publicly available data tables for testing community detection algorithms. It contains 34 nodes and 78 edges.

# %%
import sasviya.network as sasnet

# %%
# Create Graph
G = sasnet.karate_club_graph()

# %%
def run_community(G, res_level):
    outG = G.louvain(resolution=res_level)
    print(f'Communities (res={res_level})')
    for i, comm in enumerate(outG):
        print(f'comm {i+1}: {comm.nodes()}')

# %%
run_community(G, 1)
# Out:
# 2025-04-23 19:43:55,165 [ERROR   ] [183 ][_action.py     ] License check failed for feature 'CAS Action Set Soc Ntwk Analys':  The feature is not licensed.
# ---------------------------------------------------------------------------
# ActionError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_community(G, 1)
#
# Cell In[4], line 2, in run_community(G, res_level)
#       1 def run_community(G, res_level):
# ----> 2     outG = G.louvain(resolution=res_level)
#       3     print(f'Communities (res={res_level})')
#       4     for i, comm in enumerate(outG):
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/algorithms/communities.py:47, in louvain(g, edge_weight, resolution, tolerance, maxiters, data)
#      19 def louvain(g, *, edge_weight=None, resolution=1, tolerance=0.001, maxiters=100, data=True):  # numpydoc ignore=RT01
#      20     """Computes the communities of the graph by using the Louvain algorithm.
#      21
#      22     Parameters
#    (...)
#      45         `solution_summary` attribute, which contains information about the results of the algorithm.
#      46     """
# ---> 47     nodes_df, solution_summary = _louvain_runner(
#      48         g, "louvain", edge_weight=edge_weight, resolution=resolution, tolerance=tolerance, maxiters=maxiters)
#      50     def next_func(gen):
#      51         community, nodes_df = next(gen._group_iter)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/algorithms/algorithm_utils.py:158, in _load_graph.<locals>.wrapper(g, *args, **options)
#     153 if (weight_check or (_multiedges and g._gThin_id is None) or
#     154         (not _multiedges and g._graph_id is None) or change_dir_to_undir):
#     155     from sasviya.network.classes import (
#     156         class_utils,  # import here, else circular import
#     157     )
# --> 158     class_utils._load_graph(g, _multiedges=_multiedges,
#     159                             force_reload=weight_check or change_dir_to_undir, ** options)
#     160 result = func(g, *args, **kwargs)
#     161 if weight_check or (_simplified and g.allows_multiedges()) or change_dir_to_undir:
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/classes/class_utils.py:367, in _load_graph(g, data, _multiedges, _for_conversion_to_immutable, force_reload, **kwargs)
#     363     params.pop("load_undirected", None)
#     364     params.update({"direction": direction,
#     365                    "multilinks": _multiedges,
#     366                    "selflinks": g.allows_selfloops()})
# --> 367     r = LOADGRAPH_ACTION.run(**params)
#     368 if load_gThin or reload_gThin:
#     369     g._gThin_id = r.graph
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/utils/utils.py:1600, in _Action.run(self, *args, **kwargs)
#    1598     if n_threads is not None:
#    1599         kwargs["nThreads"] = n_threads
# -> 1600 retval = super().run(*args, **kwargs)
#    1601 if inspect_stack:
#    1602     _logger.debug("Completed the %s action (%s:%d)", self.action, fname, caller.lineno)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:115, in Action.run(self, cas, **kwargs)
#     113         kwargs = self._params._get_params(self._params)
#     114     logger.info("Executing %s with parameters: %s.", self, kwargs)
# --> 115     results = self._run_local(**kwargs)
#     117 # Create automatic graphics, unless disabled by the user
#     118 try:
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:191, in Action._run_local(self, **kwargs)
#     190 def _run_local(self, **kwargs):
# --> 191     return self._run_internal(self.actionset, self.action, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:186, in Action._run_internal(self, _actionset, _action, **kwargs)
#     183         _CAS_LOGGER.log(level, message)
#     185 # If action wasn't successful then raise an exception.
# --> 186 Action._check_status(self._status, results)
#     188 return results
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:805, in Action._check_status(cls, status, results)
#     803         _msg = _status
#     804 if _msg:
# --> 805     raise ActionError(status, _msg)
#
# ActionError: -2143304919: ERROR: License check failed for feature 'CAS Action Set Soc Ntwk Analys':  The feature is not licensed.

# %%
run_community(G, 0.5)
# Out:
# 2025-04-23 19:44:03,848 [ERROR   ] [183 ][_action.py     ] License check failed for feature 'CAS Action Set Soc Ntwk Analys':  The feature is not licensed.
# ---------------------------------------------------------------------------
# ActionError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 run_community(G, 0.5)
#
# Cell In[4], line 2, in run_community(G, res_level)
#       1 def run_community(G, res_level):
# ----> 2     outG = G.louvain(resolution=res_level)
#       3     print(f'Communities (res={res_level})')
#       4     for i, comm in enumerate(outG):
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/algorithms/communities.py:47, in louvain(g, edge_weight, resolution, tolerance, maxiters, data)
#      19 def louvain(g, *, edge_weight=None, resolution=1, tolerance=0.001, maxiters=100, data=True):  # numpydoc ignore=RT01
#      20     """Computes the communities of the graph by using the Louvain algorithm.
#      21
#      22     Parameters
#    (...)
#      45         `solution_summary` attribute, which contains information about the results of the algorithm.
#      46     """
# ---> 47     nodes_df, solution_summary = _louvain_runner(
#      48         g, "louvain", edge_weight=edge_weight, resolution=resolution, tolerance=tolerance, maxiters=maxiters)
#      50     def next_func(gen):
#      51         community, nodes_df = next(gen._group_iter)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/algorithms/algorithm_utils.py:158, in _load_graph.<locals>.wrapper(g, *args, **options)
#     153 if (weight_check or (_multiedges and g._gThin_id is None) or
#     154         (not _multiedges and g._graph_id is None) or change_dir_to_undir):
#     155     from sasviya.network.classes import (
#     156         class_utils,  # import here, else circular import
#     157     )
# --> 158     class_utils._load_graph(g, _multiedges=_multiedges,
#     159                             force_reload=weight_check or change_dir_to_undir, ** options)
#     160 result = func(g, *args, **kwargs)
#     161 if weight_check or (_simplified and g.allows_multiedges()) or change_dir_to_undir:
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/classes/class_utils.py:367, in _load_graph(g, data, _multiedges, _for_conversion_to_immutable, force_reload, **kwargs)
#     363     params.pop("load_undirected", None)
#     364     params.update({"direction": direction,
#     365                    "multilinks": _multiedges,
#     366                    "selflinks": g.allows_selfloops()})
# --> 367     r = LOADGRAPH_ACTION.run(**params)
#     368 if load_gThin or reload_gThin:
#     369     g._gThin_id = r.graph
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/utils/utils.py:1600, in _Action.run(self, *args, **kwargs)
#    1598     if n_threads is not None:
#    1599         kwargs["nThreads"] = n_threads
# -> 1600 retval = super().run(*args, **kwargs)
#    1601 if inspect_stack:
#    1602     _logger.debug("Completed the %s action (%s:%d)", self.action, fname, caller.lineno)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:115, in Action.run(self, cas, **kwargs)
#     113         kwargs = self._params._get_params(self._params)
#     114     logger.info("Executing %s with parameters: %s.", self, kwargs)
# --> 115     results = self._run_local(**kwargs)
#     117 # Create automatic graphics, unless disabled by the user
#     118 try:
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:191, in Action._run_local(self, **kwargs)
#     190 def _run_local(self, **kwargs):
# --> 191     return self._run_internal(self.actionset, self.action, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:186, in Action._run_internal(self, _actionset, _action, **kwargs)
#     183         _CAS_LOGGER.log(level, message)
#     185 # If action wasn't successful then raise an exception.
# --> 186 Action._check_status(self._status, results)
#     188 return results
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:805, in Action._check_status(cls, status, results)
#     803         _msg = _status
#     804 if _msg:
# --> 805     raise ActionError(status, _msg)
#
# ActionError: -2143304919: ERROR: License check failed for feature 'CAS Action Set Soc Ntwk Analys':  The feature is not licensed.

# %%
comm_dict = {node:i for i, comm in enumerate(G.louvain()) for node in comm.nodes()}
G.set_node_attributes(name='comm', values=comm_dict, inplace=True)

fig = sasnet.PlotGraph(G, layout='fdp', nodes_color_by_value='comm')
fig.show()
# Out:
# 2025-04-23 19:44:07,639 [ERROR   ] [183 ][_action.py     ] License check failed for feature 'CAS Action Set Soc Ntwk Analys':  The feature is not licensed.
# ---------------------------------------------------------------------------
# ActionError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 comm_dict = {node:i for i, comm in enumerate(G.louvain()) for node in comm.nodes()}
#       2 G.set_node_attributes(name='comm', values=comm_dict, inplace=True)
#       4 fig = sasnet.PlotGraph(G, layout='fdp', nodes_color_by_value='comm')
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/algorithms/communities.py:47, in louvain(g, edge_weight, resolution, tolerance, maxiters, data)
#      19 def louvain(g, *, edge_weight=None, resolution=1, tolerance=0.001, maxiters=100, data=True):  # numpydoc ignore=RT01
#      20     """Computes the communities of the graph by using the Louvain algorithm.
#      21
#      22     Parameters
#    (...)
#      45         `solution_summary` attribute, which contains information about the results of the algorithm.
#      46     """
# ---> 47     nodes_df, solution_summary = _louvain_runner(
#      48         g, "louvain", edge_weight=edge_weight, resolution=resolution, tolerance=tolerance, maxiters=maxiters)
#      50     def next_func(gen):
#      51         community, nodes_df = next(gen._group_iter)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/algorithms/algorithm_utils.py:158, in _load_graph.<locals>.wrapper(g, *args, **options)
#     153 if (weight_check or (_multiedges and g._gThin_id is None) or
#     154         (not _multiedges and g._graph_id is None) or change_dir_to_undir):
#     155     from sasviya.network.classes import (
#     156         class_utils,  # import here, else circular import
#     157     )
# --> 158     class_utils._load_graph(g, _multiedges=_multiedges,
#     159                             force_reload=weight_check or change_dir_to_undir, ** options)
#     160 result = func(g, *args, **kwargs)
#     161 if weight_check or (_simplified and g.allows_multiedges()) or change_dir_to_undir:
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/classes/class_utils.py:367, in _load_graph(g, data, _multiedges, _for_conversion_to_immutable, force_reload, **kwargs)
#     363     params.pop("load_undirected", None)
#     364     params.update({"direction": direction,
#     365                    "multilinks": _multiedges,
#     366                    "selflinks": g.allows_selfloops()})
# --> 367     r = LOADGRAPH_ACTION.run(**params)
#     368 if load_gThin or reload_gThin:
#     369     g._gThin_id = r.graph
#
# File /usr/local/lib/python3.11/site-packages/sasviya/network/utils/utils.py:1600, in _Action.run(self, *args, **kwargs)
#    1598     if n_threads is not None:
#    1599         kwargs["nThreads"] = n_threads
# -> 1600 retval = super().run(*args, **kwargs)
#    1601 if inspect_stack:
#    1602     _logger.debug("Completed the %s action (%s:%d)", self.action, fname, caller.lineno)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:115, in Action.run(self, cas, **kwargs)
#     113         kwargs = self._params._get_params(self._params)
#     114     logger.info("Executing %s with parameters: %s.", self, kwargs)
# --> 115     results = self._run_local(**kwargs)
#     117 # Create automatic graphics, unless disabled by the user
#     118 try:
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:191, in Action._run_local(self, **kwargs)
#     190 def _run_local(self, **kwargs):
# --> 191     return self._run_internal(self.actionset, self.action, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:186, in Action._run_internal(self, _actionset, _action, **kwargs)
#     183         _CAS_LOGGER.log(level, message)
#     185 # If action wasn't successful then raise an exception.
# --> 186 Action._check_status(self._status, results)
#     188 return results
#
# File /usr/local/lib/python3.11/site-packages/sasviya/core/_action.py:805, in Action._check_status(cls, status, results)
#     803         _msg = _status
#     804 if _msg:
# --> 805     raise ActionError(status, _msg)
#
# ActionError: -2143304919: ERROR: License check failed for feature 'CAS Action Set Soc Ntwk Analys':  The feature is not licensed.
